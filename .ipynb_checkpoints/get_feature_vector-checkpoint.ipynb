# %%
import matplotlib.pyplot as plt
import numpy as np
import nltk
import pandas as pd
import TraverseDir.TraverseDir as td
import pandas_toolkit.mytoolkit as tk

# %%
#read csv files:name and path

# %%
rootDir = '/Users/wangmu/Documents/Science/mG1/数据/sec'

# %%
file_path_list = td.show_all_path(rootDir)
file_name_list = td.get_filename(file_path_list)

# %%
#overview alldata in rootDir
len(file_name_list)
# Out:
# 8193

# %%
# overview all data in our lab

#testdir = '/Users/wangmu/Desktop/laballdata'
#file_path_list = td.show_all_path(testdir)
#file_name_list = td.get_filename(file_path_list)
#len(file_name_list)

# >49593

# %%
# make list[('name',pandas.df),...]
data_list = []
for finame,fipath in zip(file_name_list,file_path_list):
#try:
    #print(fipath)
    data_pair= (finame,tk.onestep_norm_peak2zero(fipath))
    data_list.append(data_pair)
    
#Except TypeError as error:
#   with open('error.txt','w') as error_fi:
#       print(error,file=error_fi)
#   pass

ss = data_list
# Out:
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/5415.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/5426.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6899.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6900.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6901.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6902.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6903.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6904.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6905.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6906.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6907.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6908.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6909.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6910.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6911.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6912.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6913.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6914.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6915.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6916.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6917.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6918.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6919.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6920.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6921.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/6922.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/4852.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/4853.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/5415.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/5431.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/5440.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6899.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6900.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6901.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6902.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6903.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6904.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6905.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6906.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6907.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6908.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6909.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6910.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6911.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6912.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6913.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6914.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6931.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6932.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6933.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6934.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6935.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6936.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6937.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6938.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6939.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6940.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6941.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6942.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6943.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6944.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6945.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6946.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6947.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/6948.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/7010.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/7015.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/7017.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/7018.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/7019.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170426/20170426SEC 45SAMPLES/7020.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6915.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6916.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6917.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6918.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6919.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6920.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6921.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6922.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6923.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6924.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6925.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6926.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6927.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6928.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6929.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/6930.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/7031.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/7032.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/7034.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429SEC 16SAMPLES/7038.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/5415-3.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/5415.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/5426-3-2.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/5426-3.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/5426.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/5431.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/5440.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6734-3.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6931.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6932.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6933.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6934.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6935.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6936.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6937.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6938.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6939.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6940.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6941.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6942.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6943.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6944.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6945.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6946.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6947.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/6948.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7034.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7067-3.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7068-3.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7069-3.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7092.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7093.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7094.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7095.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7096.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7097.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7098.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7099.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7100.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7101.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7102.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7103.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7104.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7105.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7106.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7107.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170516/20170516sec/7108.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170520/20170520sec copy/5415-2.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170520/20170520sec copy/5415.CSV
# /Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170520/20170520sec copy/5426-2.CSV
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a0a590e35e65> in <module>
#       4 #try:
#       5     print(fipath)
# ----> 6     data_pair= (finame,tk.onestep_norm_peak2zero(fipath))
#       7     data_list.append(data_pair)
#       8
#
# ~/Documents/GitHub/sec_analyse/sec_analyse/pandas_toolkit/mytoolkit.py in onestep_norm_peak2zero(filepath)
#      80     fi = pandas_read_sec_csv(fi)
#      81     # pick region(2.5,5.0)
# ---> 82     fi = pick_x_region(fi,(2.5,5.0))
#      83     # normalize
#      84     fi = normalize_peak2zero(fi)
#
# ~/Documents/GitHub/sec_analyse/sec_analyse/pandas_toolkit/mytoolkit.py in pick_x_region(df, x_interval)
#      21     if isinstance(df,pandas.core.frame.DataFrame):
#      22         df = df.copy()
# ---> 23         df = df.where((df.time<x_interval[1])&(df.time>x_interval[0]))
#      24         return df
#      25
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast, raise_on_error)
#    8832         other = com.apply_if_callable(other, self)
#    8833         return self._where(cond, other, inplace, axis, level,
# -> 8834                            errors=errors, try_cast=try_cast)
#    8835
#    8836     @Appender(_shared_docs['where'] % dict(_shared_doc_kwargs, cond="False",
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8565         cond = com.apply_if_callable(cond, self)
#    8566         if isinstance(cond, NDFrame):
# -> 8567             cond, _ = cond.align(self, join='right', broadcast_axis=1)
#    8568         else:
#    8569             if not hasattr(cond, 'shape'):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    3662                                          fill_value=fill_value, method=method,
#    3663                                          limit=limit, fill_axis=fill_axis,
# -> 3664                                          broadcast_axis=broadcast_axis)
#    3665
#    3666     def rename(self, index=None, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    8403                                        level=level, copy=copy,
#    8404                                        fill_value=fill_value, method=method,
# -> 8405                                        limit=limit, fill_axis=fill_axis)
#    8406             elif isinstance(other, Series):
#    8407                 # this means self is a DataFrame, and we need to broadcast
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _align_frame(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    8457         left = self._reindex_with_indexers(reindexers, copy=copy,
#    8458                                            fill_value=fill_value,
# -> 8459                                            allow_dups=True)
#    8460         # other must be always DataFrame
#    8461         right = other._reindex_with_indexers({0: [join_index, iridx],
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4491
#    4492         if copy and new_data is self._data:
# -> 4493             new_data = new_data.copy()
#    4494
#    4495         return self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in copy(self, deep)
#     732             new_axes = list(self.axes)
#     733         return self.apply('copy', axes=new_axes, deep=deep,
# --> 734                           do_integrity_check=False)
#     735
#     736     def as_array(self, transpose=False, items=None):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in copy(self, deep)
#     752         if deep:
#     753             values = values.copy()
# --> 754         return self.make_block_same_class(values)
#     755
#     756     def replace(self, to_replace, value, inplace=False, filter=None,
#
# KeyboardInterrupt:

# %%
ff = '/Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170423 6899-6922/Shodex/5415.CSV'

# %%
ss = tk.onestep_norm_peak2zero(ff)

# %%
ss
# Out:
#       time  peak
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# 5      NaN   NaN
# 6      NaN   NaN
# 7      NaN   NaN
# 8      NaN   NaN
# 9      NaN   NaN
# 10     NaN   NaN
# 11     NaN   NaN
# 12     NaN   NaN
# 13     NaN   NaN
# 14     NaN   NaN
# 15     NaN   NaN
# 16     NaN   NaN
# 17     NaN   NaN
# 18     NaN   NaN
# 19     NaN   NaN
# 20     NaN   NaN
# 21     NaN   NaN
# 22     NaN   NaN
# 23     NaN   NaN
# 24     NaN   NaN
# 25     NaN   NaN
# 26     NaN   NaN
# 27     NaN   NaN
# 28     NaN   NaN
# 29     NaN   NaN
# ...    ...   ...
# 3271   NaN   NaN
# 3272   NaN   NaN
# 3273   NaN   NaN
# 3274   NaN   NaN
# 3275   NaN   NaN
# 3276   NaN   NaN
# 3277   NaN   NaN
# 3278   NaN   NaN
# 3279   NaN   NaN
# 3280   NaN   NaN
# 3281   NaN   NaN
# 3282   NaN   NaN
# 3283   NaN   NaN
# 3284   NaN   NaN
# 3285   NaN   NaN
# 3286   NaN   NaN
# 3287   NaN   NaN
# 3288   NaN   NaN
# 3289   NaN   NaN
# 3290   NaN   NaN
# 3291   NaN   NaN
# 3292   NaN   NaN
# 3293   NaN   NaN
# 3294   NaN   NaN
# 3295   NaN   NaN
# 3296   NaN   NaN
# 3297   NaN   NaN
# 3298   NaN   NaN
# 3299   NaN   NaN
# 3300   NaN   NaN
#
# [3301 rows x 2 columns]

# %%
aa = pd.DataFrame(file_path_list,columns=['filepath'])

# %%
aa.to_csv('aa.csv')

# %%
7317 in file_name_list
# Out:
# False

# %%
bb = tk.pandas_read_sec_csv('/Users/wangmu/Documents/Science/mG1/数据/sec/2017/20170429实验结果/20170429CPM 16SAMPLES/1.csv')

# %%
bb
# Out:
#                                                 time  peak
# 0  㤶㔱 ㄠ⸰〰 㠠⸵〰䕟㍸㜸〮䔰㑭㌶〮弰慒灭ⰱ㘬ㄹ弶†〱〮弰†㔸〮弰硅㠳⸷〰浅㘴⸳〰剟浡ㅰⰬ㤶...   NaN

# %%
bb.time.dtype
print(bb.peak.dtype)
# Out:
# float64

# %%
isinstance(bb.peak.dtype,float)
# Out:
# False

# %%
bb.peak.dtype ==float
# Out:
# True
