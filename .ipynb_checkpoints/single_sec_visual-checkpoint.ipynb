# %%
import matplotlib.pyplot as plt
import numpy as np
import nltk
import pandas as pd

# %%
import mytoolkit as mt

# %%
pp1 =mt.pandas_read_sec_csv('/Users/wangmu/Documents/Science/mG1/数据/sec/20190624/6D-11631.CSV')
pp2 =mt.pandas_read_sec_csv('/Users/wangmu/Documents/Science/mG1/数据/sec/20190624/6D-11624.CSV')

# %%
plt.plot(pp1.time,pp1.peak)
plt.plot(pp2.time,pp2.peak)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
pp1 = mt.pick_x_region(pp1,(2.5,5.0))
pp2 = mt.pick_x_region(pp2,(2.5,5.0))
plt.plot(pp1.time,pp1.peak)
plt.plot(pp2.time,pp2.peak)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
pp1= mt.normalize_peak2zero(pp1)
pp2= mt.normalize_peak2zero(pp2)
plt.plot(pp1.time,pp1.peak)
plt.plot(pp2.time,pp2.peak)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
pp1= mt.normalize_peak2max(pp1)
pp2= mt.normalize_peak2max(pp2)
plt.plot(pp1.time,pp1.peak)
plt.plot(pp2.time,pp2.peak)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#done
